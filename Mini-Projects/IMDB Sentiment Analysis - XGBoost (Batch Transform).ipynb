# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# As our first example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there may be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %%
# !pwd
# Out:
# /home/ec2-user/SageMaker/udacity-mle-sagemaker-deployment/Mini-Projects

# %%
# %%capture
# Make sure that we use SageMaker 1.x
# !pip install sagemaker==1.72.0
# For sending text messages
# !pip install twilio

# %%
import sys
sys.path.insert(0, '..')
from twilio_helper import twilio_helper
notebook_name = 'IMDB Sentiment Analysis - XGBoost (Batch Transform).ipynb'
twilio_helper.send_text_message(notebook_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-aa60ed4ce8de> in <module>
#       1 import sys
#       2 sys.path.insert(0, '..')
# ----> 3 from twilio_helper import twilio_helper
#       4 notebook_name = 'IMDB Sentiment Analysis - XGBoost (Batch Transform).ipynb'
#       5 twilio_helper.send_text_message(notebook_name)
#
# ~/SageMaker/udacity-mle-sagemaker-deployment/twilio_helper/twilio_helper.py in <module>
#       7 # Your Account Sid and Auth Token from twilio.com/console
#       8 # and set the environment variables. See http://twil.io/secure
# ----> 9 account_sid = os.environ['TWILIO_ACCOUNT_SID']
#      10 auth_token = os.environ['TWILIO_AUTH_TOKEN']
#      11 client = Client(account_sid, auth_token)
#
# ~/anaconda3/envs/python3/lib/python3.6/os.py in __getitem__(self, key)
#     667         except KeyError:
#     668             # raise KeyError with the original key value
# --> 669             raise KeyError(key) from None
#     670         return self.decodevalue(value)
#     671
#
# KeyError: 'TWILIO_ACCOUNT_SID'

# %%
import os
import glob
import pickle
import re
from bs4 import BeautifulSoup
# from sklearn.externals import joblib
import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri

import numpy as np
import pandas as pd
import sklearn
from sklearn.utils import shuffle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score

import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# --2021-03-30 10:25:22--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  12.2MB/s    in 12s
#
# 2021-03-30 10:25:34 (6.46 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
# %%time
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg
# CPU times: user 1.15 s, sys: 393 ms, total: 1.54 s
# Wall time: 1.56 s

# %%
# from sklearn.utils import shuffle
def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# "A different look at horror. The styling differences between American and Russian films is interesting. However from my American perspective this movie just wasn't that good. The protagonist, Marie played by Anastasia Hille wasn't a pleasant character and I had a hard time identifying with her. She was disagreeable most of the time and confused for much of what little time was left. Also too much time was spent in bringing her to the main location of the film. Then a long time passed before any real suspense built up. Once that happened it seemed volume was used as the main effect which was more annoying than anything else. The concept was more original than most Direct-to-video movies and they didn't use sex to make up for a thin plot. All in all I'd recommend it for renting, but not for theater goers."

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
stemmer = PorterStemmer()

# %%
# import re
# from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
# import pickle
cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# %%time
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Read preprocessed data from cache file: preprocessed_data.pkl
# CPU times: user 813 ms, sys: 217 ms, total: 1.03 s
# Wall time: 1.03 s

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
#             pass  # unable to read from cache, but that's okay
            print("Unable to read features from cache file:", cache_file)
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# %%time
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
twilio_helper.send_text_message(f'{notebook_name}: extract bag of words finished')

# Read features from cache file: bow_features.pkl
# Wall time: 7min 10s
# Out:
# Read features from cache file: bow_features.pkl
# Text message sent: SM56bfc95ff1d644c78e2bc9176acd6022
# CPU times: user 284 ms, sys: 723 ms, total: 1.01 s
# Wall time: 1.17 s

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### (TODO) Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
# TODO: Split the train_X and train_y arrays into the DataFrames val_X, train_X and val_y, train_y. Make sure that
#       val_X and val_y contain 10 000 entires while train_X and train_y contain the remaining 15 000 entries.
train_X, val_X, train_y, val_y = sklearn.model_selection.train_test_split(
    pd.DataFrame(train_X), pd.DataFrame(train_y), test_size=0.4)
print(train_X.shape, val_X.shape, train_y.shape, val_y.shape)
# Out:
# (15000, 5000) (10000, 5000) (15000, 1) (10000, 1)

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

# TODO: Save the training and validation data to train.csv and validation.csv in the data_dir directory.
#       Make sure that the files you create are in the correct format.
# Note: the first column is the label
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)
pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.
test_X = train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### (TODO) Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# import sagemaker
session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

# TODO: Upload the test.csv, train.csv and validation.csv files which are contained in data_dir to S3 using sess.upload_data().
# data_dir = '../data/xgboost'
test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating the XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. To begin with, we need to do some setup. At this point it is worth discussing what a model is in SageMaker. It is easiest to think of a model of comprising three different objects in the SageMaker ecosystem, which interact with one another.
#
# - Model Artifacts
# - Training Code (Container)
# - Inference Code (Container)
#
# The Model Artifacts are what you might think of as the actual model itself. For example, if you were building a neural network, the model artifacts would be the weights of the various layers. In our case, for an XGBoost model, the artifacts are the actual trees that are created during training.
#
# The other two objects, the training code and the inference code are then used the manipulate the training artifacts. More precisely, the training code uses the training data that is provided and creates the model artifacts, while the inference code uses the model artifacts to make predictions on new data.
#
# The way that SageMaker runs the training and inference code is by making use of Docker containers. For now, think of a container as being a way of packaging code up so that dependencies aren't an issue.

# %%
# from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()
print(role)
# Out:
# arn:aws:iam::616964915547:role/service-role/AmazonSageMaker-ExecutionRole-20210330T032993

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.

# from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(session.boto_region_name, 'xgboost', '1.0-1')
print(container)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.
xgb = sagemaker.estimator.Estimator(container, # The image name of the training container
                                    role,      # The IAM role to use (our current role in this case)
                                    train_instance_count=1, # The number of instances to use for training
                                    train_instance_type='ml.m4.xlarge', # The type of instance to use for training
                                    output_path=f's3://{session.default_bucket()}/{prefix}/output',
                                        # Where to save the output (the model artifacts) 
                                        # prefix = 'sentiment-xgboost'
                                    sagemaker_session=session) # The current SageMaker session

# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        objective='binary:logistic',
#                         early_stopping_rounds=10,
                        num_round=200 # this is a mandatory hyperparameter
                       )
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# ### Fit the XGBoost model
#
# Now that our model has been set up we simply need to attach the training and validation datasets and then ask SageMaker to set up the computation.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
# %%time
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
twilio_helper.send_text_message(f'{notebook_name}: training finished')

# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# https://github.com/aws/sagemaker-python-sdk/issues/613
# Out:
# 2021-04-01 01:10:36 Starting - Starting the training job...
# 2021-04-01 01:10:39 Starting - Launching requested ML instances.........
# 2021-04-01 01:12:34 Starting - Preparing the instances for training......
# 2021-04-01 01:13:29 Downloading - Downloading input data...
# 2021-04-01 01:13:56 Training - Downloading the training image...
# 2021-04-01 01:14:34 Training - Training image download completed. Training in progress...INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [01:14:40] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [01:14:42] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# INFO:root:Train matrix has 15000 rows
# INFO:root:Validation matrix has 10000 rows
# [01:14:42] WARNING: /workspace/src/learner.cc:328:
# Parameters: { num_round } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]#011train-error:0.29553#011validation-error:0.30590
# [1]#011train-error:0.27967#011validation-error:0.28620
# [2]#011train-error:0.28093#011validation-error:0.28850
# [3]#011train-error:0.26313#011validation-error:0.27160
# [4]#011train-error:0.25853#011validation-error:0.27220
# [5]#011train-error:0.25587#011validation-error:0.26840
# [6]#011train-error:0.25227#011validation-error:0.26720
# [7]#011train-error:0.24407#011validation-error:0.25840
# [8]#011train-error:0.23667#011validation-error:0.24880
# [9]#011train-error:0.22807#011validation-error:0.24420
# [10]#011train-error:0.22080#011validation-error:0.23860
# [11]#011train-error:0.21813#011validation-error:0.23610
# [12]#011train-error:0.20920#011validation-error:0.22660
# [13]#011train-error:0.20620#011validation-error:0.22380
# [14]#011train-error:0.20313#011validation-error:0.22280
# [15]#011train-error:0.20180#011validation-error:0.21920
# [16]#011train-error:0.19820#011validation-error:0.21630
# [17]#011train-error:0.19633#011validation-error:0.21460
# [18]#011train-error:0.19507#011validation-error:0.21160
# [19]#011train-error:0.19027#011validation-error:0.20830
# [20]#011train-error:0.18773#011validation-error:0.20650
# [21]#011train-error:0.18473#011validation-error:0.20400
# [22]#011train-error:0.18093#011validation-error:0.20180
# [23]#011train-error:0.17960#011validation-error:0.20090
# [24]#011train-error:0.17820#011validation-error:0.19870
# [25]#011train-error:0.17613#011validation-error:0.19810
# [26]#011train-error:0.17420#011validation-error:0.19530
# [27]#011train-error:0.17227#011validation-error:0.19470
# [28]#011train-error:0.16893#011validation-error:0.19320
# [29]#011train-error:0.16900#011validation-error:0.19160
# [30]#011train-error:0.16687#011validation-error:0.19110
# [31]#011train-error:0.16227#011validation-error:0.18980
# [32]#011train-error:0.15873#011validation-error:0.18750
# [33]#011train-error:0.15787#011validation-error:0.18660
# [34]#011train-error:0.15720#011validation-error:0.18590
# [35]#011train-error:0.15560#011validation-error:0.18330
# [36]#011train-error:0.15327#011validation-error:0.18240
# [37]#011train-error:0.15113#011validation-error:0.18220
# [38]#011train-error:0.14960#011validation-error:0.18130
# [39]#011train-error:0.14827#011validation-error:0.17850
# [40]#011train-error:0.14740#011validation-error:0.17980
# [41]#011train-error:0.14620#011validation-error:0.18120
# [42]#011train-error:0.14553#011validation-error:0.18000
# [43]#011train-error:0.14367#011validation-error:0.17890
# [44]#011train-error:0.14320#011validation-error:0.17770
# [45]#011train-error:0.14047#011validation-error:0.17830
# [46]#011train-error:0.14000#011validation-error:0.17720
# [47]#011train-error:0.13880#011validation-error:0.17430
# [48]#011train-error:0.13800#011validation-error:0.17420
# [49]#011train-error:0.13580#011validation-error:0.17340
# [50]#011train-error:0.13633#011validation-error:0.17390
# [51]#011train-error:0.13467#011validation-error:0.17380
# [52]#011train-error:0.13420#011validation-error:0.17240
# [53]#011train-error:0.13480#011validation-error:0.17010
# [54]#011train-error:0.13267#011validation-error:0.16860
# [55]#011train-error:0.13147#011validation-error:0.16760
# [56]#011train-error:0.13060#011validation-error:0.16900
# [57]#011train-error:0.12993#011validation-error:0.16820
# [58]#011train-error:0.12913#011validation-error:0.16800
# [59]#011train-error:0.12933#011validation-error:0.16770
# [60]#011train-error:0.12787#011validation-error:0.16730
# [61]#011train-error:0.12733#011validation-error:0.16610
# [62]#011train-error:0.12660#011validation-error:0.16560
# [63]#011train-error:0.12607#011validation-error:0.16570
# [64]#011train-error:0.12507#011validation-error:0.16450
# [65]#011train-error:0.12367#011validation-error:0.16430
# [66]#011train-error:0.12340#011validation-error:0.16340
# [67]#011train-error:0.12307#011validation-error:0.16340
# [68]#011train-error:0.12260#011validation-error:0.16270
# [69]#011train-error:0.12233#011validation-error:0.16270
# [70]#011train-error:0.12173#011validation-error:0.16210
# [71]#011train-error:0.12087#011validation-error:0.16120
# [72]#011train-error:0.12020#011validation-error:0.16220
# [73]#011train-error:0.11947#011validation-error:0.16200
# [74]#011train-error:0.11900#011validation-error:0.16130
# [75]#011train-error:0.11920#011validation-error:0.16110
# [76]#011train-error:0.11847#011validation-error:0.16150
# [77]#011train-error:0.11760#011validation-error:0.16050
# [78]#011train-error:0.11620#011validation-error:0.16060
# [79]#011train-error:0.11593#011validation-error:0.16000
# [80]#011train-error:0.11587#011validation-error:0.16010
# [81]#011train-error:0.11593#011validation-error:0.15940
# [82]#011train-error:0.11527#011validation-error:0.15880
# [83]#011train-error:0.11427#011validation-error:0.15840
# [84]#011train-error:0.11380#011validation-error:0.15820
# [85]#011train-error:0.11287#011validation-error:0.15620
# [86]#011train-error:0.11220#011validation-error:0.15590
# [87]#011train-error:0.11127#011validation-error:0.15640
# [88]#011train-error:0.11067#011validation-error:0.15580
# [89]#011train-error:0.10987#011validation-error:0.15540
# [90]#011train-error:0.11013#011validation-error:0.15510
# [91]#011train-error:0.10967#011validation-error:0.15530
# [92]#011train-error:0.10847#011validation-error:0.15370
# [93]#011train-error:0.10780#011validation-error:0.15340
# [94]#011train-error:0.10667#011validation-error:0.15390
# [95]#011train-error:0.10587#011validation-error:0.15360
# [96]#011train-error:0.10533#011validation-error:0.15180
# [97]#011train-error:0.10480#011validation-error:0.15160
# [98]#011train-error:0.10507#011validation-error:0.15190
# [99]#011train-error:0.10467#011validation-error:0.15280
# [100]#011train-error:0.10427#011validation-error:0.15240
# [101]#011train-error:0.10380#011validation-error:0.15400
# [102]#011train-error:0.10307#011validation-error:0.15290
# [103]#011train-error:0.10207#011validation-error:0.15400
# [104]#011train-error:0.10167#011validation-error:0.15380
# [105]#011train-error:0.10193#011validation-error:0.15280
# [106]#011train-error:0.10220#011validation-error:0.15260
# [107]#011train-error:0.10173#011validation-error:0.15240
# [108]#011train-error:0.10160#011validation-error:0.15170
# [109]#011train-error:0.10167#011validation-error:0.15170
# [110]#011train-error:0.10140#011validation-error:0.15230
# [111]#011train-error:0.10020#011validation-error:0.15160
# [112]#011train-error:0.10013#011validation-error:0.15040
# [113]#011train-error:0.09967#011validation-error:0.15090
# [114]#011train-error:0.09947#011validation-error:0.14950
# [115]#011train-error:0.09853#011validation-error:0.14990
# [116]#011train-error:0.09853#011validation-error:0.14970
# [117]#011train-error:0.09807#011validation-error:0.15050
# [118]#011train-error:0.09733#011validation-error:0.14980
# [119]#011train-error:0.09740#011validation-error:0.14950
# [120]#011train-error:0.09713#011validation-error:0.14860
# [121]#011train-error:0.09693#011validation-error:0.14890
# [122]#011train-error:0.09740#011validation-error:0.14900
# [123]#011train-error:0.09693#011validation-error:0.14870
# [124]#011train-error:0.09640#011validation-error:0.14820
# [125]#011train-error:0.09633#011validation-error:0.14840
# [126]#011train-error:0.09627#011validation-error:0.14820
# [127]#011train-error:0.09587#011validation-error:0.14770
# [128]#011train-error:0.09573#011validation-error:0.14820
# [129]#011train-error:0.09600#011validation-error:0.14810
# [130]#011train-error:0.09487#011validation-error:0.14730
# [131]#011train-error:0.09387#011validation-error:0.14750
# [132]#011train-error:0.09400#011validation-error:0.14620
# [133]#011train-error:0.09353#011validation-error:0.14670
# [134]#011train-error:0.09340#011validation-error:0.14670
# [135]#011train-error:0.09280#011validation-error:0.14630
# [136]#011train-error:0.09247#011validation-error:0.14670
# [137]#011train-error:0.09220#011validation-error:0.14620
# [138]#011train-error:0.09120#011validation-error:0.14620
# [139]#011train-error:0.09107#011validation-error:0.14600
# [140]#011train-error:0.09153#011validation-error:0.14630
# [141]#011train-error:0.09100#011validation-error:0.14600
# [142]#011train-error:0.09107#011validation-error:0.14620
# [143]#011train-error:0.09140#011validation-error:0.14520
# [144]#011train-error:0.09167#011validation-error:0.14510
# [145]#011train-error:0.09133#011validation-error:0.14470
# [146]#011train-error:0.09107#011validation-error:0.14430
# [147]#011train-error:0.09093#011validation-error:0.14410
# [148]#011train-error:0.09080#011validation-error:0.14370
# [149]#011train-error:0.09067#011validation-error:0.14410
# [150]#011train-error:0.09013#011validation-error:0.14380
# [151]#011train-error:0.08980#011validation-error:0.14400
# [152]#011train-error:0.08953#011validation-error:0.14380
# [153]#011train-error:0.08933#011validation-error:0.14270
# [154]#011train-error:0.08913#011validation-error:0.14270
# [155]#011train-error:0.08900#011validation-error:0.14240
# [156]#011train-error:0.08827#011validation-error:0.14240
# [157]#011train-error:0.08787#011validation-error:0.14260
# [158]#011train-error:0.08793#011validation-error:0.14270
# [159]#011train-error:0.08760#011validation-error:0.14260
# [160]#011train-error:0.08773#011validation-error:0.14310
# [161]#011train-error:0.08753#011validation-error:0.14210
# [162]#011train-error:0.08647#011validation-error:0.14220
# [163]#011train-error:0.08653#011validation-error:0.14260
# [164]#011train-error:0.08593#011validation-error:0.14280
# [165]#011train-error:0.08607#011validation-error:0.14170
# [166]#011train-error:0.08553#011validation-error:0.14210
# [167]#011train-error:0.08507#011validation-error:0.14160
# [168]#011train-error:0.08433#011validation-error:0.14150
# [169]#011train-error:0.08400#011validation-error:0.14160
# [170]#011train-error:0.08347#011validation-error:0.14170
# [171]#011train-error:0.08247#011validation-error:0.14190
# [172]#011train-error:0.08247#011validation-error:0.14180
# [173]#011train-error:0.08213#011validation-error:0.14130
# [174]#011train-error:0.08247#011validation-error:0.14100
# [175]#011train-error:0.08247#011validation-error:0.14100
# [176]#011train-error:0.08247#011validation-error:0.14100
# [177]#011train-error:0.08233#011validation-error:0.14160
# [178]#011train-error:0.08220#011validation-error:0.14180
# [179]#011train-error:0.08193#011validation-error:0.14180
# [180]#011train-error:0.08207#011validation-error:0.14100
# [181]#011train-error:0.08200#011validation-error:0.14160
# [182]#011train-error:0.08200#011validation-error:0.14080
# [183]#011train-error:0.08180#011validation-error:0.14070
# [184]#011train-error:0.08153#011validation-error:0.14070
# [185]#011train-error:0.08093#011validation-error:0.14050
# [186]#011train-error:0.08067#011validation-error:0.14030
# [187]#011train-error:0.08007#011validation-error:0.13930
# [188]#011train-error:0.07987#011validation-error:0.13970
# [189]#011train-error:0.07933#011validation-error:0.13870
# [190]#011train-error:0.07927#011validation-error:0.13900
# [191]#011train-error:0.07840#011validation-error:0.13860
# [192]#011train-error:0.07900#011validation-error:0.13840
# [193]#011train-error:0.07867#011validation-error:0.13830
# [194]#011train-error:0.07887#011validation-error:0.13840
# [195]#011train-error:0.07913#011validation-error:0.13830
# [196]#011train-error:0.07860#011validation-error:0.13820
# [197]#011train-error:0.07827#011validation-error:0.13850
# [198]#011train-error:0.07820#011validation-error:0.13840
# [199]#011train-error:0.07820#011validation-error:0.13830
#
# 2021-04-01 01:19:42 Uploading - Uploading generated training model
# 2021-04-01 01:19:42 Completed - Training job completed
# Training seconds: 373
# Billable seconds: 373
# Text message sent: SMae751e5989d74f56b40386de378d6cb6
# CPU times: user 1.31 s, sys: 50.3 ms, total: 1.36 s
# Wall time: 9min 17s

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've fit our XGBoost model, it's time to see how well it performs. To do this we will use SageMakers Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# To perform a Batch Transformation we need to first create a transformer objects from our trained estimator object.

# %%
# TODO: Create a transformer object from the trained model. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.
xgb_transformer = xgb.transformer(instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
# %%time
xgb_transformer.wait()
twilio_helper.send_text_message(f'{notebook_name}: validation finished')
# Out:
# ................................[2021-04-01:01:26:01:INFO] No GPUs detected (normal if no gpus installed)
# [2021-04-01:01:26:01:INFO] No GPUs detected (normal if no gpus installed)
# [2021-04-01:01:26:01:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# [2021-04-01:01:26:01:INFO] No GPUs detected (normal if no gpus installed)
# [2021-04-01:01:26:01:INFO] No GPUs detected (normal if no gpus installed)
# [2021-04-01:01:26:01:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# [2021-04-01 01:26:02 +0000] [17] [INFO] Starting gunicorn 19.10.0
# [2021-04-01 01:26:02 +0000] [17] [INFO] Listening at: unix:/tmp/gunicorn.sock (17)
# [2021-04-01 01:26:02 +0000] [17] [INFO] Using worker: gevent
# [2021-04-01 01:26:02 +0000] [24] [INFO] Booting worker with pid: 24
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# [2021-04-01 01:26:02 +0000] [17] [INFO] Starting gunicorn 19.10.0
# [2021-04-01 01:26:02 +0000] [17] [INFO] Listening at: unix:/tmp/gunicorn.sock (17)
# [2021-04-01 01:26:02 +0000] [17] [INFO] Using worker: gevent
# [2021-04-01 01:26:02 +0000] [24] [INFO] Booting worker with pid: 24
# [2021-04-01 01:26:02 +0000] [25] [INFO] Booting worker with pid: 25
# [2021-04-01 01:26:02 +0000] [26] [INFO] Booting worker with pid: 26
# [2021-04-01 01:26:02 +0000] [27] [INFO] Booting worker with pid: 27
# [2021-04-01 01:26:02 +0000] [25] [INFO] Booting worker with pid: 25
# [2021-04-01 01:26:02 +0000] [26] [INFO] Booting worker with pid: 26
# [2021-04-01 01:26:02 +0000] [27] [INFO] Booting worker with pid: 27
# [2021-04-01:01:26:07:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [01/Apr/2021:01:26:07 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:07:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [01/Apr/2021:01:26:07 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:07:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [01/Apr/2021:01:26:07 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:07:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [01/Apr/2021:01:26:07 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# 2021-04-01T01:26:07.988:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2021-04-01:01:26:11:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:11:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:11:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:11:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:13 +0000] "POST /invocations HTTP/1.1" 200 12182 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:13 +0000] "POST /invocations HTTP/1.1" 200 12182 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:13 +0000] "POST /invocations HTTP/1.1" 200 12209 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:14:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:14 +0000] "POST /invocations HTTP/1.1" 200 12236 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:14 +0000] "POST /invocations HTTP/1.1" 200 12210 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:14:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:14:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:13 +0000] "POST /invocations HTTP/1.1" 200 12209 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:14:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:14 +0000] "POST /invocations HTTP/1.1" 200 12236 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:14 +0000] "POST /invocations HTTP/1.1" 200 12210 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:14:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:14:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:14:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:14:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:17 +0000] "POST /invocations HTTP/1.1" 200 12216 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:17 +0000] "POST /invocations HTTP/1.1" 200 12192 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:17 +0000] "POST /invocations HTTP/1.1" 200 12239 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:17:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:17:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:17 +0000] "POST /invocations HTTP/1.1" 200 12216 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:17 +0000] "POST /invocations HTTP/1.1" 200 12192 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:17 +0000] "POST /invocations HTTP/1.1" 200 12239 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:17:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:17:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:17 +0000] "POST /invocations HTTP/1.1" 200 12215 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:17:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:17:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:17 +0000] "POST /invocations HTTP/1.1" 200 12215 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:17:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:17:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:20 +0000] "POST /invocations HTTP/1.1" 200 12213 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:20 +0000] "POST /invocations HTTP/1.1" 200 12205 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:20 +0000] "POST /invocations HTTP/1.1" 200 12213 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:20 +0000] "POST /invocations HTTP/1.1" 200 12205 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:20 +0000] "POST /invocations HTTP/1.1" 200 12223 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:20:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:20:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:20 +0000] "POST /invocations HTTP/1.1" 200 12269 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:20:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:20:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:20 +0000] "POST /invocations HTTP/1.1" 200 12223 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:20:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:20:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:20 +0000] "POST /invocations HTTP/1.1" 200 12269 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:20:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:20:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:23:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:24:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:23:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:24:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:26 +0000] "POST /invocations HTTP/1.1" 200 12231 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:26 +0000] "POST /invocations HTTP/1.1" 200 12245 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:26 +0000] "POST /invocations HTTP/1.1" 200 12247 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:26:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:26:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:27 +0000] "POST /invocations HTTP/1.1" 200 12254 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:27:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:27:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:26 +0000] "POST /invocations HTTP/1.1" 200 12231 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:26 +0000] "POST /invocations HTTP/1.1" 200 12245 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:26 +0000] "POST /invocations HTTP/1.1" 200 12247 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:26:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:26:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:27 +0000] "POST /invocations HTTP/1.1" 200 12254 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:27:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:27:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:29 +0000] "POST /invocations HTTP/1.1" 200 12224 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:29 +0000] "POST /invocations HTTP/1.1" 200 12260 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:29 +0000] "POST /invocations HTTP/1.1" 200 12224 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:29 +0000] "POST /invocations HTTP/1.1" 200 12260 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:30 +0000] "POST /invocations HTTP/1.1" 200 12273 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:30:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:30 +0000] "POST /invocations HTTP/1.1" 200 12213 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:30:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:30:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:30:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:30 +0000] "POST /invocations HTTP/1.1" 200 12273 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:30:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:30 +0000] "POST /invocations HTTP/1.1" 200 12213 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:30:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:30:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:30:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:33 +0000] "POST /invocations HTTP/1.1" 200 12213 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:33 +0000] "POST /invocations HTTP/1.1" 200 12204 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:33 +0000] "POST /invocations HTTP/1.1" 200 12262 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:33:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:33:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:33 +0000] "POST /invocations HTTP/1.1" 200 12237 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:33 +0000] "POST /invocations HTTP/1.1" 200 12213 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:33 +0000] "POST /invocations HTTP/1.1" 200 12204 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:33 +0000] "POST /invocations HTTP/1.1" 200 12262 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:33:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:33:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:33 +0000] "POST /invocations HTTP/1.1" 200 12237 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:33:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:33:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:33:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:33:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:36 +0000] "POST /invocations HTTP/1.1" 200 12210 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:36:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:36 +0000] "POST /invocations HTTP/1.1" 200 12225 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:36:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:36:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:36:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:36 +0000] "POST /invocations HTTP/1.1" 200 12210 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:36:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:36 +0000] "POST /invocations HTTP/1.1" 200 12225 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:36:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:36:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:36:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:39 +0000] "POST /invocations HTTP/1.1" 200 12218 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:39 +0000] "POST /invocations HTTP/1.1" 200 12209 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:39 +0000] "POST /invocations HTTP/1.1" 200 12218 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:39 +0000] "POST /invocations HTTP/1.1" 200 12209 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [01/Apr/2021:01:26:39 +0000] "POST /invocations HTTP/1.1" 200 12232 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:39:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:39 +0000] "POST /invocations HTTP/1.1" 200 12206 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:39:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:39:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:39:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:39 +0000] "POST /invocations HTTP/1.1" 200 12232 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:39:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [01/Apr/2021:01:26:39 +0000] "POST /invocations HTTP/1.1" 200 12206 "-" "Go-http-client/1.1"
# [2021-04-01:01:26:39:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:39:INFO] Determined delimiter of CSV input is ','
# [2021-04-01:01:26:39:INFO] Determined delimiter of CSV input is ','
#
# Text message sent: SMef3882e3deb74f14847180319375d2ff
# CPU times: user 880 ms, sys: 35.1 ms, total: 915 ms
# Wall time: 6min 15s

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-616964915547/sagemaker-xgboost-2021-04-01-01-20-13-105/test.csv.out to ../data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
# from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.86876

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
